# %%
x_value = [0, 1, 2, 3, 4]

# %%
x_value, len(x_value)
# Out:
# ([0, 1, 2, 3, 4], 5)

# %%
y_value = [1, 3, 5, 7, 9]
y_value, len(y_value)
# Out:
# ([1, 3, 5, 7, 9], 5)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=x_value, y=y_value)
